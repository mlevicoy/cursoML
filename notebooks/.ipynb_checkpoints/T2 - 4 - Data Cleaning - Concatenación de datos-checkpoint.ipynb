# %% [markdown]
# ## Concatenar datos

# %%
# Importamos la librería
import pandas as pd

# %%
# Cargamos el dataset y creamos el DataFrame para los vinos tintos
red_wine = pd.read_csv("../datasets/wine/winequality-red.csv", sep=";")
# Mostramos la cabecera
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# mostramos las columnas
red_wine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
# Mostramos la cantidad de filas x columnas
red_wine.shape
# Out:
# (1599, 12)

# %%
# Cargamos el dataset y creamos el DataFrame para el vino blanco
white_wine = pd.read_csv("../datasets/wine/winequality-white.csv", sep=";")
# Mostramos la cabecera
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
# Mostramos las columnas
white_wine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
# Mostramos la cantidad de filas x columnas
white_wine.shape
# Out:
# (4898, 12)

# %% [markdown]
# En Python, tenemos dos tipos de ejes,
#
# * axis=0, denota el eje orizontal
# * axis=1, denota el eje vertical

# %%
# Concatenamos con concat, en el orden en que se escribe
wine_data = pd.concat([red_wine, white_wine], axis=0)

# %%
# Revisamos la concatenación
wine_data.shape
# Out:
# (6497, 12)

# %%
# Unimos varias secciones
data1 = wine_data.head(10)
data2 = wine_data[300:310]
data3 = wine_data.tail(10)

# %%
wine_scramble = pd.concat([data1, data2, data3], axis=0)

# %%
wine_scramble
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 9               7.5             0.500         0.36            6.10      0.071
# 300             7.5             0.530         0.06            2.60      0.086
# ...

# %%
wine_scramble = pd.concat([data2, data3, data1], axis=0)

# %%
wine_scramble
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 300             7.5             0.530         0.06            2.60      0.086
# 301            11.1             0.180         0.48            1.50      0.068
# 302             8.3             0.705         0.12            2.60      0.092
# 303             7.4             0.670         0.12            1.60      0.186
# 304             8.4             0.650         0.60            2.10      0.112
# 305            10.3             0.530         0.48            2.50      0.063
# 306             7.6             0.620         0.32            2.20      0.082
# 307            10.3             0.410         0.42            2.40      0.213
# 308            10.3             0.430         0.44            2.40      0.214
# 309             7.4             0.290         0.38            1.70      0.062
# 4888            6.8             0.220         0.36            1.20      0.052
# ...

# %% [markdown]
# ## Datos distribuidos

# %%
# Importamos la librería
import pandas as pd

# %%
# Cargamos el primer DataSet para tener con quien concatenar
data = pd.read_csv("../datasets/distributed-data/001.csv")
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
data.shape
# Out:
# (1461, 4)

# %% [markdown]
# * Importar el primer fichero.
# * Hacemos un bucle para ir recorriendo todos y cada uno de los ficheros.
#     * Importante tener una consistencia en el nombre de los ficheros.
#     * Importamos los ficheros uno a uno.
#     * Cada uno de ellos deben aprendizarse (añadir al final) del primer fichero que ya habiamos cargado
# * Repetimos el bucle hasta que no queden ficheros

# %%
filepath = "../datasets/distributed-data/"

data = pd.read_csv("../datasets/distributed-data/001.csv")

final_length = len(data)

for i in range(2, 333):
    if i < 10:
        filename = "00" + str(i)
    elif 10 <= i < 100:
        filename = "0" + str(i)
    elif i >= 100:
        filename = str(i)
    
    file = filepath + filename + ".csv"
    temp_data = pd.read_csv(file)
    
    final_length += len(temp_data)
    
    data = pd.concat([data, temp_data], axis=0)

# %%
data.shape
# Out:
# (772087, 4)

# %%
final_length
# Out:
# 772087

# %%
final_length == data.shape[0]
# Out:
# True

# %% [markdown]
# ## Joins de datasets

# %%
filepath = "../datasets/athletes/"
# Muestra atletas, año de participacion y medallas
data_main = pd.read_csv(filepath + "Medals.csv", encoding="ISO-8859-1")

# %%
data_main.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8
# 1              0              2             8
# 2              2              0             6
# 3              2              3             6
# 4              1              3             6

# %%
# A simple vista se repiten los atletas, para eliminar las atletas repetidos se hace:
a = data_main["Athlete"].unique().tolist()
len(a)
# Out:
# 6956

# %%
# El data_main contiene:
data_main.shape
# Out:
# (8618, 8)

# %%
# Muestra los atletas y su pais de origen
data_country = pd.read_csv(filepath + "Athelete_Country_Map.csv", encoding="ISO-8859-1")

# %%
data_country.head()
# Out:
#             Athlete        Country
# 0    Michael Phelps  United States
# 1  Natalie Coughlin  United States
# 2     Aleksey Nemov         Russia
# 3     Alicia Coutts      Australia
# 4    Missy Franklin  United States

# %%
len(data_country)
# Out:
# 6970

# %%
# La cantidad de elementos es mayor, es debido a que 1 atleta represente a dos paises
data_country[data_country["Athlete"] == "Aleksandar Ciric"]
# Out:
#                Athlete                Country
# 1029  Aleksandar Ciric                 Serbia
# 1086  Aleksandar Ciric  Serbia and Montenegro

# %%
# Muestra los atletas con su deporte
data_sports = pd.read_csv(filepath + "Athelete_Sports_Map.csv", encoding="ISO-8859-1")

# %%
data_sports.head()
# Out:
#             Athlete       Sport
# 0    Michael Phelps    Swimming
# 1  Natalie Coughlin    Swimming
# 2     Aleksey Nemov  Gymnastics
# 3     Alicia Coutts    Swimming
# 4    Missy Franklin    Swimming

# %%
len(data_sports)
# Out:
# 6975

# %%
# Las cantidades no son iguales porque hay atletas que practicas varias disciplinas, ejemplo:
data_sports[(data_sports["Athlete"] == "Chen Jing") | 
            (data_sports["Athlete"] == "Richard Thompson") | 
            (data_sports["Athlete"] == "Matt Ryan") 
           ]
# Out:
#                Athlete         Sport
# 528   Richard Thompson     Athletics
# 1308         Chen Jing    Volleyball
# 1419         Chen Jing  Table Tennis
# 2727         Matt Ryan        Rowing
# 5003         Matt Ryan    Equestrian
# 5691  Richard Thompson      Baseball

# %%
data_country_dp = data_country.drop_duplicates(subset="Athlete")

# %%
len(data_country_dp) == len(a)
# Out:
# True

# %%
data_main_country = pd.merge(left=data_main, right=data_country, left_on="Athlete", right_on="Athlete")

# %%
data_main_country.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States
# 2              2              0             6  United States
# 3              2              3             6  United States
# 4              2              1             5  United States

# %%
# Se estan duplicando algunos datos
data_main_country.shape
# Out:
# (8657, 9)

# %%
data_main_country[data_main_country["Athlete"] == "Aleksandar Ciric"]
# Out:
#                Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 1503  Aleksandar Ciric  30.0  2008            08/24/2008            0
# 1504  Aleksandar Ciric  30.0  2008            08/24/2008            0
# 1505  Aleksandar Ciric  26.0  2004            08/29/2004            0
# 1506  Aleksandar Ciric  26.0  2004            08/29/2004            0
# 1507  Aleksandar Ciric  22.0  2000            10/01/2000            0
# 1508  Aleksandar Ciric  22.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals                Country
# 1503              0              1             1                 Serbia
# 1504              0              1             1  Serbia and Montenegro
# 1505              1              0             1                 Serbia
# 1506              1              0             1  Serbia and Montenegro
# 1507              0              1             1                 Serbia
# ...

# %%
data_sports_dp = data_sports.drop_duplicates(subset="Athlete")

# %%
len(data_sports_dp) == len(a)
# Out:
# True

# %%
data_final = pd.merge(left=data_main_country, right=data_sports_dp, left_on="Athlete", right_on="Athlete")

# %%
data_final.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country     Sport
# 0              0              0             8  United States  Swimming
# 1              0              2             8  United States  Swimming
# 2              2              0             6  United States  Swimming
# 3              2              3             6  United States  Swimming
# 4              2              1             5  United States  Swimming

# %%
data_final.shape
# Out:
# (8657, 10)

# %% [markdown]
# ## Tipo de Joins

# %%
from IPython.display import Image
import numpy as np

# %% [markdown]
# **Inner Join <= A (Left Join), B (Right Join) <= Outer Join**

# %% [markdown]
# ### Inner Join

# %% [markdown]
# * Devuelve un data frame con las filas que tienen valor tanto en el primer como
#   en el segundo data frame que estamos uniendo.
# * El número de filas será igual al número de filas comunes que tengan ambos sets.
#     * Data Set A tiene 60 filas.
#     * Data Set B tiene 50 filas.
#     * Ambos comparten 30 filas.
#     * Entonces A Inner Join B tendrá 30 filas.
# * En terminos de teoría de conjuntos, se trata de la intersección de los dos conjuntos.

# %%
 # Atletas que se deben mantener
out_athletes = np.random.choice(data_main["Athlete"], size = 6, replace = False)

# %%
# Se elimina todo menos los atletas de arriba y Michael Phelps
data_country_dlt = data_country_dp[(~data_country_dp["Athlete"].isin(out_athletes)) & 
                                  (data_country_dp["Athlete"] != "Michael Phelps")]

data_sports_dlt = data_sports_dp[(~data_sports_dp["Athlete"].isin(out_athletes)) & 
                                  (data_sports_dp["Athlete"] != "Michael Phelps")]

data_main_dlt = data_main[(~data_main["Athlete"].isin(out_athletes)) & 
                                  (data_main["Athlete"] != "Michael Phelps")]

# %%
len(data_country_dlt)
# Out:
# 6949

# %%
len(data_sports_dlt)
# Out:
# 6949

# %%
len(data_main_dlt)
# Out:
# 8608

# %%
data_country_dlt.head()
# Out:
#             Athlete        Country
# 1  Natalie Coughlin  United States
# 2     Aleksey Nemov         Russia
# 3     Alicia Coutts      Australia
# 4    Missy Franklin  United States
# 5       Ryan Lochte  United States

# %%
Image(filename="../datasets/join/inner-join.png")

# %%
# data_main contiene toda la info
# data_country_dlt le falta la info de 7 atletas
merged_inner = pd.merge(left=data_main, right=data_country_dlt,
                       how="inner", left_on="Athlete", right_on="Athlete")

# %%
merged_inner.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0  Natalie Coughlin  25.0  2008            08/24/2008            1
# 1  Natalie Coughlin  21.0  2004            08/29/2004            2
# 2  Natalie Coughlin  29.0  2012            08/12/2012            0
# 3     Aleksey Nemov  24.0  2000            10/01/2000            2
# 4     Alicia Coutts  24.0  2012            08/12/2012            1
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              2              3             6  United States
# 1              2              1             5  United States
# 2              0              1             1  United States
# 3              1              3             6         Russia
# 4              3              1             5      Australia

# %% [markdown]
# ### Left Join

# %% [markdown]
# * Devuelve un data frame con las filas que tuvieran valor en el dataset
#   de la izquierda, sin importar si tienen correspondencia en el de la
#   derecha o no.
# * Las filas del data frame final será igual al número de filas del data
#   frame izquierdo.
#     * Data Set A tiene 60 filas.
#     * Data Set B tiene 50 filas.
#     * Entonces, A Left Join B tendrá 60 filas.
# * En términos teoría de conjuntos, se trata del propio data set de izquierda
#   quien, además tiene la intersercción en su interior.

# %%
Image(filename="../datasets/join/left-join.png")

# %%
merged_left = pd.merge(left=data_main, right=data_country_dlt, how="left", left_on="Athlete", right_on="Athlete")

# %%
merged_left.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8            NaN
# 1              0              2             8            NaN
# 2              2              0             6            NaN
# 3              2              3             6  United States
# 4              1              3             6         Russia

# %% [markdown]
# ### Right Join

# %% [markdown]
# * Devuelve un data frame con las filas que tuvieran valor en el dataframe de la derecha, sin importar si tiene correspondencia en el izquierdo o no.
# * Las filas del data frame final que no correspondan a ninguna fila del data frame izquierdo, tendrán NaN en las columnas del data frame izquierdo.
# * El número de filas será igual al número de filas del data frame derecho.
#     * Data Set A tiene 60 filas.
#     * Data Set B tiene 50 filas.
#     * Entonces, A Right Join B tendrá 50 filas.
# * En terminos de teoria de conjuntos, se trata del propio data set de la derecha quien, además tiene la intersección en su interior.

# %%
Image(filename="../datasets/join/right-join.png")

# %%
merged_right = pd.merge(left=data_main_dlt, right=data_country_dp, how="right", left_on="Athlete", right_on="Athlete")

# %%
merged_right.head()
# Out:
#             Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps   NaN     NaN                   NaN          NaN
# 1  Natalie Coughlin  25.0  2008.0            08/24/2008          1.0
# 2  Natalie Coughlin  21.0  2004.0            08/29/2004          2.0
# 3  Natalie Coughlin  29.0  2012.0            08/12/2012          0.0
# 4     Aleksey Nemov  24.0  2000.0            10/01/2000          2.0
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0            NaN            NaN           NaN  United States
# 1            2.0            3.0           6.0  United States
# 2            2.0            1.0           5.0  United States
# 3            0.0            1.0           1.0  United States
# 4            1.0            3.0           6.0         Russia

# %% [markdown]
# ### Outer Join

# %% [markdown]
# * Devuelve un data frame con todas las filas de ambos, reemplazando las ausencias de uno o de otro con NaN en la región específica.
# * Las filas del data frame final que no correspondan a ninguna fila del data frame derecho (o izquierdo), tendrán NaN en las columnas del data frame derecho (o izquierdo).
# * El número de filas será igual al máximo número de filas de ambos data frames.
#     * Data Set A tiene 60 filas.
#     * Data Set B tiene 50 filas.
#     * Entonces, A Outer Join B tendrá 60 + 50 = 80 filas.
# * En términos de teoría de conjuntos, se trata de la unión de conjuntos.

# %%
Image(filename="../datasets/join/outer-join.png")

# %%
data_country_jb = data_country_dlt.append(
    {
        "Athlete" : "Juan Gabriel Gomila",
        "Country" : "España"
    },ignore_index = True
)
# Out:
# C:\Users\mlevi\AppData\Local\Temp/ipykernel_16040/4247257061.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_country_jb = data_country_dlt.append(

# %%
merged_outer = pd.merge(left=data_main, right=data_country_jb, how="outer", left_on="Athlete", right_on="Athlete")

# %%
merged_outer.head()
# Out:
#             Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008.0            08/24/2008          8.0
# 1    Michael Phelps  19.0  2004.0            08/29/2004          6.0
# 2    Michael Phelps  27.0  2012.0            08/12/2012          4.0
# 3  Natalie Coughlin  25.0  2008.0            08/24/2008          1.0
# 4  Natalie Coughlin  21.0  2004.0            08/29/2004          2.0
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0            0.0            0.0           8.0            NaN
# 1            0.0            2.0           8.0            NaN
# 2            2.0            0.0           6.0            NaN
# 3            2.0            3.0           6.0  United States
# 4            2.0            1.0           5.0  United States
